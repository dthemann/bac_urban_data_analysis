# %% [markdown]
# # 07/09/2023
# - Exploring Ideas in Company
#     - Discussing with colleagues the idea of analysing compaction control data from earthwork and asphalt rollers
#     - Discussing with colleagues the idea of analysing the operational data from asphalt mixing plants
#     - Approaching colleagues regardinng availabel data from machinery park
#     - Approaching colleagues from Data Science Team regarding potentail projects for Bachelor Thesis
#
# # 09/09/2023
# - Proposal Development
#     - Researching asphalt mixing process
#     - Reseraching asphalt mixing technology
#     - Youtubing about asphalt mixing plants and technolgy
#     - Defining problem statement
#     - Reseraching sustainabilty data from construction industry
#
# # 10/09/2023
# - Proposal Development
#     - Drafting Introduction & Motiviation Section
#     - Drafting State-of-the-Art Section
#     - Mapping out timeplan
#     - Summaring proposal in Abstract
#
# - Exploration Pandas Library
#     - What are Dataframes
#     https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html
#     https://www.w3schools.com/python/pandas/pandas_dataframes.asp
#     - What analysis methods (clustering)
#     https://scikit-learn.org/stable/modules/clustering.html
#
# # 11/09/2023
# - Arraning appointments with colleague about current data science projects with asphalt mixing plants
#
# # 12/09/2023
# - Proposal Development
#     - Review and submission of proposal
#
# # 13/09/2023
# - Proposal Presentation
#     - Discussion of proposal and feedback session in class
#
# # 15/09/2023
# - Review of current asphalt mixing plants data science project
#     - Reviewing existing data base
#     - Reviewing existing data analyis methods
#     - Reviewing visualization with QickSense
#     - Exploring potential relations of potential data factors
#     - Drafting list of correlations
#
# # 18/09/2023
# - Consultation with colleagues from machinery department (Plan B)
#     - Discussing about what data is available
#     - What analysis has already been done with the data
#     - What interfaces are availabel to collect data
#
# >**What approvals from CML are required for a data science projects**
#
# # 20/09/2023
# - Consultation with asphalt mixing plant experts / operators
#     - What data is available from which plants
#         - What data can be obtained via API/automatic interfaces
#         - What data is additionally collected and who?
#     - What data analyis has already been done?
#     - What data analyis would be valuable for the asphalt mixing plant operational processes
#     - What additional data can be obtained when new interfaces are requested from asphalt mixing plant technology provider
#
# >**Open questions regarding who is asking which parnter what, i.e. approaching tech. partners**
#
# # 22/09/2023
# - Consultation with asphalt mixing plant experts / operators
#     - Additional data is required for further improvments of asphalt mixing plant operational process
#     - Data is available at each individual plant to operators but not centrally stored
#     - Adding required APIs by asphalt mixing plant provider requires development cost and time beyond project and potentially realized savings
#     - Data not available in required quality, i.e. energy consumption only for entire processing plant - no spit between bitumen heating system and mixing plant; no fill gauge for bitumen storage; etc.
#
# >**Decision to search for newest asphalt mixing plants in corproate**
#
# # 26/09/2023
# - Consultation with asphalt mixing plant experts / operators
#     - Newest mixing plants have no centralized data API
#     - Newest mixing plants have no operational history worth analysing, i.e. less than 1.5 years
#
# >**Giving up idea about analysing asphalt mixing plant data**
#
# >**Resorting to idea of analysing machinery data**
#
# # 27/09/2023
# - Evaluating remaining ideas for data science projects within corporate
#
# >**Machinery data analysis is seen as completed by management**
#
# >**Limited avaibility of strucuted data in organiation**
#
# - Lunch meeting with colleague from Real Estate Development Branch of corporate
# - Discussing ideas about predictability of real estate market
# - Evaluating ideas about real estate market predictions
#     - What can be predicted
#     - What data is available
#     - What is the value certain predictions
#
# # 29/09/2023
# - Research on big data analytics projects in the real estate market
#     - Google Scholar, WU Wien and Technikum libraries
#
# >**Reserach mostly focused on GeoInformation-Data based models**
#
# >**Reserach papers focus on predicting the geographical development of cities and town, i.e. expansion**
#
# >**Reserach papers neglect impact of/on real estate development market**
#
# >**Research papers don't integrate factors like population growth and demographic strucutres**
#
# # 01/10/2023
# - Research on big data analytics projects in urban development
#     - Google Scholar, WU Wien and Technikum libraries
# >**Research on policy design governing urban expansion very limited**
#
# >**Policy Design often referred to as art rather than science**
#
# >**Papers on COVID-19 measures explore the combination of policy design, data science and policy impacts**
#
# # 03/10/2023
# - Exploring publically availabe data on cities and town
#     - GIS Data available for
#         - Austria https://www.geoland.at/
#         - Europe https://inspire-geoportal.ec.europa.eu/srv/ger/catalog.search#/home
#
#     - Statistical data available via
#         - ARDECO EU Commission Data Base https://urban.jrc.ec.europa.eu/ardeco/explorer?lng=en
#         - Eurostats
#
# # 06/10/2023
# - Exploring Eurostats and ARDECO Database
#     - What data is availabel at which abstraction levels (NUTS classifications)
#     - Exploring differences between cities, town and metropolitan areas
#     - Exploring what looks like a good data base for reserach
#
# # 08/10/2023
# - Reseraching Social-Economic Model Design
#     - What factors are considered as important
#
# >**Demography, Polulation, Education, Business activities**
#
# # 10/10/2023
# - Reseraching what data for the development of socio-econometric models is availabe
#     - ARDECO provides recent data sets across differnt NUTS classifications
#     - Eurostats provides data set on cities with data quality differnt from country to country
#
# # 13/10/2023
# - Downloading Publically availalbe data on Cities from ARDECO and Eurostats
#     - Population, Education and business activities
# - Comparing data quality across data sets from metropoliton regions (ARDECO) and cities (Eurostats)
# - Exploring Eurostats platform for additional data sets
#
# >**Eurostat provides datasets of limited quality for cities; missing data not likely to be compensated by additional data from Eurostats, i.e. compelementing data at city level with regional level**
#
# # 15/10/2023
# - Importing dataset into notebook
# - Getting used to pandas
# - Restructuring data sets in dataframes
#
# # 19/10/2023
# - Exploring how many full data sets will be available
#     - Deleting empty rows / columns with drop
#     - Rearranging dataframes
#
# # 22/10/2023
# - Creating code that allows to dynamically select range of years from dataset
# - Adding a code module that allows to clean dataset from empty row and columns
#
# >**When empty row and columns are deleted a very small data set remains for a period of 10 years.**
#
# # 25/10/2023
# - Exploring methods to augment data with pandas
#     - Exploring application of Pandas Interpolate function with parameter linear
#     https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.interpolate.html
#     - Testing differn parameters of interpolate function with existing data set
#
# >**Interpolate works to fill data voids (empty cells between two valid values) but does not extrapolate values, i.e. adds missing data at the end of rows**
#
# >**Interpolate pad-fills missing values at the beginning and end of row**
#
# # 30/10/2023
# - Exploring alternatives to interpolate function
#     - Exploring applciation fo Pandas Interpolate function wiht parameter "spline"
#     - Testing spline with existing data set
#
# >**Interpolate with parameter helpful for extrapolating data; yet failed to pad empty cells in the middle of data set**
#
# # 01/11/2023
# - Exploring combination of Interpolate parameters "linear" and "spline"
#     - Sequencing Interpolate functions
#     - Comparing resulting data frames
#
# >**Combining Interpolate("Linear") with Interpolate("SPLINE") function. First linear interpolation to fill data voids (only forward) afterwards interpolate with spline to extrapolate data**
#
# # 07/11/2023
# - Combining all dataframe in one dictionary
# - Writing code so that routine works trough dataframe in dictionary
#
# # 11/11/2023
# - Faschingsbeginn
#
# # 12/11/2023
# - Exploring Matplotlib library for data visualization
# - Exploring potential for data to be displayed in scatter plots
#
# # 15/11/2023
# - Exploring opportunities to display data in 3D scatter plots
#
# # 18/11/2023
# - Segregating dataframe to individual cities
# - Exploring pandas.corr functions
#
# # 26/11/2023
# - Exploring differencess in pandas.corr fuctions
# - Youtubing Statistics 101
# - Screening differences in Pearson, Kendall, Spearman correlations
#
# # 30/11/2023
# - Comparing different corr Methods with city data sets
#
# >**Deciding for Spearman correlation method since cities can experience temporal shocks yet a positive correlation is given over the time frame of X years**
#
# # 03/12/2023
# - Exploing matplotlib and opporunities to display corr-matrix
#
# # 10/12/2023
# - Finding Seaborn library
# - Screening heatmap plots
# - Exploring how to display corr-matrix via seaborn
#
# # 17/12/2023
# - Comining city based data frames to dictionary
# - Screening matplotlib and seaborn library to for opporunities to display an overlay of city-corr matrix in one graph
#
# # 20/12/2023
# - Proposal Draft Revision
#     - Reserach urban policy design papers
#     - Reserach methodology for data science projects
#
# # 28/12/2023
# - Proposal Draft Revision
#     - Drafting Motivation and Introduction section
# - Reserach on EU-wide urban policy design resources
#
# # 30/12/2023
# - Review EU Green Deal and measures
# - Researching facts and figures of cities in the EU
#
# # 03/01/2024
# - Review Proposal Abstract section
# - Review Proposal State-of-the-Art section
#
# # 04/01/2024
# - Research for Data Science Methodology
#     - Found description of methodology in several bachelor and master theses
# - Draft methodolog section of proposal
#
#
# # 05/01/2024
# - Revision of Proposal
# - Review of cited sources and citations
#
# # 06/01/2024
# - Editorial review of propoals
#
# # 07/01/2024
# - Editorial review of proposal
# - Submission of proposal
